# %%
import pandas as pd
import numpy as np

# %%
df_fake = pd.read_csv('/home/jovyan/work/data/Fake3.csv',encoding='utf-8')
df_fake
# Out:
#                                                  title  \
# 0                             นายทักษิณขยับ เรือนจำผวา
# 1    “พล.ต.อ.เสรีพิศุทธ์” ฟันธง “บิ๊กโจ๊ก” ชนะปมออก...
# 2               ขาดทุนยับประกาศปิดกิจการโละพนักงานทิ้ง
# 3    คนเหนือบอกว่า คนไม่ดี เหยียบเมือง มันจะร้อนเเล...
# 4    ก็เลือกมันมาแล้วเนาะ ทำไงได้ล่ะ ก้มหน้าก้มตาให...
# ..                                                 ...
# 995  กรมการขนส่งทางบก เตือน!!! ประชาชนอย่าหลงเชื่อเ...
# 996       ศาลฯ ประสานสหรัฐฯ ขอข้อมูลคดีรับสินบนโตโยต้า
# 997  นวัตกรรมแผ่นแปะ Keep On Sleep ช่วยให้นอนหลับอย...
# 998  ธนาคารออมสิน เติมสภาพคล่องผู้ประกอบการ SMEs จั...
# 999      ดื่มน้ำเย็นเป็นสาเหตุทำให้ผู้หญิงอ้วนลงพุงได้
#
#                                                   body      type     W/D/Y  \
# 0    [นายทักษิณขยับเรือนจำผวา]\n.\nสื่อหลายสำนักพาด...  การเมือง  28/04/67
# 1    "พล.ต.อ.เสรีพิศุทธ์" ฟันธง "บิ๊กโจ๊ก" ชนะปมออก...  การเมือง  28/04/67
# 2    ได้ยินข่าวช่องว้ายทีวี ซึ่งมีทายาทของมหาเศรษฐี...  การเมือง  02/05/67
# 3    คนเหนือบอกว่า คนไม่ดี เหยียบเมือง มันจะร้อนเเล...  การเมือง  02/05/67
# 4    เพื่อไทยเป็นรัฐบาล ค่าไฟ ค่าน้ำมัน ค่าแกส ลดทั...  การเมือง  26/04/67
# ..                                                 ...       ...       ...
# 995  กรมการขนส่งทางบก เตือน!!! ประชาชนอย่าหลงเชื่อเ...    ทั่วไป  25/12/66
# 996  เลขาธิการสำนักงานศาลยุติธรรม เผยเร่งตรวจสอบข้อ...  การเมือง  04/06/64
# 997  นวัตกรรมแผ่นแปะ Keep On Sleep ซึ่งพัฒนาโดย Eng...    สุขภาพ  01/05/67
# 998  กรณีการพบเพจเฟซบุ๊กที่ใช้ชื่อว่า สินเชื่อธุรกิ...  เศรษฐกิจ  19/01/63
# 999  “ดื่มน้ำเย็น ตอนอากาศร้อน” ไม่ได้อันตรายนะครับ...    สุขภาพ  19/08/67
#
#                                                    url  \
# 0    https://www.facebook.com/groups/93837253660692...
# 1    https://www.topnews.co.th/news/953843?fbclid=I...
# 2    https://www.facebook.com/groups/93837253660692...
# 3    https://www.facebook.com/groups/93837253660692...
# 4    https://www.facebook.com/groups/93837253660692...
# ..                                                 ...
# 995  https://www.dlt.go.th/th/public-news/3475/?emb...
# 996      https://www.thaipbs.or.th/news/content/304933
# 997               https://www.chula.ac.th/news/157476/
# 998  https://www.gsb.or.th/news/%E0%B8%98%E0%B8%99%...
# 999  https://sasuksure.anamai.moph.go.th/content.ph...
#
#                                 main url
# 0               https://www.facebook.com
# 1              https://www.topnews.co.th
# 2               https://www.facebook.com
# 3               https://www.facebook.com
# 4               https://www.facebook.com
# ..                                   ...
# 995                https://www.dlt.go.th
# 996            https://www.thaipbs.or.th
# 997              https://www.chula.ac.th
# 998                https://www.gsb.or.th
# 999  https://sasuksure.anamai.moph.go.th
#
# [1000 rows x 6 columns]

# %%
txt = df_fake['body']
txt
# Out:
# 0      [นายทักษิณขยับเรือนจำผวา]\n.\nสื่อหลายสำนักพาด...
# 1      "พล.ต.อ.เสรีพิศุทธ์" ฟันธง "บิ๊กโจ๊ก" ชนะปมออก...
# 2      ได้ยินข่าวช่องว้ายทีวี ซึ่งมีทายาทของมหาเศรษฐี...
# 3      คนเหนือบอกว่า คนไม่ดี เหยียบเมือง มันจะร้อนเเล...
# 4      เพื่อไทยเป็นรัฐบาล ค่าไฟ ค่าน้ำมัน ค่าแกส ลดทั...
#                              ...
# 995    กรมการขนส่งทางบก เตือน!!! ประชาชนอย่าหลงเชื่อเ...
# 996    เลขาธิการสำนักงานศาลยุติธรรม เผยเร่งตรวจสอบข้อ...
# 997    นวัตกรรมแผ่นแปะ Keep On Sleep ซึ่งพัฒนาโดย Eng...
# 998    กรณีการพบเพจเฟซบุ๊กที่ใช้ชื่อว่า สินเชื่อธุรกิ...
# 999    “ดื่มน้ำเย็น ตอนอากาศร้อน” ไม่ได้อันตรายนะครับ...
# Name: body, Length: 1000, dtype: object

# %%
t = str(txt)
t
# Out:
# '0      [นายทักษิณขยับเรือนจำผวา]\\n.\\nสื่อหลายสำนักพาด...\n1      "พล.ต.อ.เสรีพิศุทธ์" ฟันธง "บิ๊กโจ๊ก" ชนะปมออก...\n2      ได้ยินข่าวช่องว้ายทีวี ซึ่งมีทายาทของมหาเศรษฐี...\n3      คนเหนือบอกว่า คนไม่ดี เหยียบเมือง มันจะร้อนเเล...\n4      เพื่อไทยเป็นรัฐบาล ค่าไฟ ค่าน้ำมัน ค่าแกส ลดทั...\n                             ...                        \n995    กรมการขนส่งทางบก เตือน!!! ประชาชนอย่าหลงเชื่อเ...\n996    เลขาธิการสำนักงานศาลยุติธรรม เผยเร่งตรวจสอบข้อ...\n997    นวัตกรรมแผ่นแปะ Keep On Sleep ซึ่งพัฒนาโดย Eng...\n998    กรณีการพบเพจเฟซบุ๊กที่ใช้ชื่อว่า สินเชื่อธุรกิ...\n999    “ดื่มน้ำเย็น ตอนอากาศร้อน” ไม่ได้อันตรายนะครับ...\nName: body, Length: 1000, dtype: object'

# %%
import re
import pythainlp
from pythainlp.corpus import thai_stopwords
from pythainlp.tokenize import word_tokenize
import string
from pythainlp.util import normalize
from pythainlp.tokenize import newmm

# %%
cleaned_text = re.sub('[^ก-๙]', '', t)
cleaned_text
# Out:
# 'นายทักษิณขยับเรือนจำผวาสื่อหลายสำนักพาดพลตอเสรีพิศุทธ์ฟันธงบิ๊กโจ๊กชนะปมออกได้ยินข่าวช่องว้ายทีวีซึ่งมีทายาทของมหาเศรษฐีคนเหนือบอกว่าคนไม่ดีเหยียบเมืองมันจะร้อนเเลเพื่อไทยเป็นรัฐบาลค่าไฟค่าน้ำมันค่าแกสลดทักรมการขนส่งทางบกเตือนประชาชนอย่าหลงเชื่อเเลขาธิการสำนักงานศาลยุติธรรมเผยเร่งตรวจสอบข้อนวัตกรรมแผ่นแปะซึ่งพัฒนาโดยกรณีการพบเพจเฟซบุ๊กที่ใช้ชื่อว่าสินเชื่อธุรกิดื่มน้ำเย็นตอนอากาศร้อนไม่ได้อันตรายนะครับ'

# %%
normalized_text= normalize(cleaned_text)
normalized_text
# Out:
# 'นายทักษิณขยับเรือนจำผวาสื่อหลายสำนักพาดพลตอเสรีพิศุทธ์ฟันธงบิ๊กโจ๊กชนะปมออกได้ยินข่าวช่องว้ายทีวีซึ่งมีทายาทของมหาเศรษฐีคนเหนือบอกว่าคนไม่ดีเหยียบเมืองมันจะร้อนแลเพื่อไทยเป็นรัฐบาลค่าไฟค่าน้ำมันค่าแกสลดทักรมการขนส่งทางบกเตือนประชาชนอย่าหลงเชื่อแลขาธิการสำนักงานศาลยุติธรรมเผยเร่งตรวจสอบข้อนวัตกรรมแผ่นแปะซึ่งพัฒนาโดยกรณีการพบเพจเฟซบุ๊กที่ใช้ชื่อว่าสินเชื่อธุรกิดื่มน้ำเย็นตอนอากาศร้อนไม่ได้อันตรายนะครับ'

# %%
stop_words = set(thai_stopwords())
stop_words
# Out:
# {'มั้ย',
#  'ครั้งคราว',
#  'บัดนั้น',
#  'คราที่',
#  'เปิดเผย',
#  'ข้างๆ',
#  'ขึ้น',
#  'ด้วยเช่นกัน',
#  'หากแม้',
#  'ใช่ไหม',
#  'ใครๆ',
#  'ทําให้',
#  'หลัง',
#  'มุ่ง',
#  'ยิ่งขึ้นไป',
#  'เชื่อ',
#  'เรา',
#  'ภายภาคหน้า',
#  'หรือไม่',
#  'กว่า',
#  'อื่น',
#  'เน้น',
#  'ทุกสิ่ง',
#  'เมื่อเย็น',
#  'เข้าใจ',
#  'ด้วยเหตุที่',
#  'ช่วงต่อไป',
#  'ถึงเมื่อไร',
#  'พวกมึง',
#  'เหลือเกิน',
#  'วันไหน',
#  'ภายนอก',
#  'ใดๆ',
#  'ช่วงก่อน',
#  'พวกที่',
#  'เช่นเคย',
#  'เสร็จแล้ว',
#  'เมื่อครั้ง',
#  'เผื่อจะ',
#  'เพราะฉะนั้น',
#  'จึงเป็น',
#  'เลย',
#  'บางกว่า',
#  'เมื่อวันวาน',
#  'อาจเป็น',
#  'ดั่งเก่า',
#  'ทุก',
#  'แต่ละ',
#  'เป็นอัน',
#  'มั้ยเนี่ย',
#  'พวกนั้น',
#  'แต่',
#  'ก็ตามแต่',
#  'รวมๆ',
#  'เคย',
#  'น้อยกว่า',
#  'ที่ได้',
#  'ยิ่ง',
#  'ที่นี้',
#  'ทั้งเป็น',
#  'ยิ่งเมื่อ',
#  'อันเนื่องมาจาก',
#  'ฝ่าย',
#  'เป็นที่',
#  'ให้',
#  'จนทั่ว',
#  'จนเมื่อ',
#  'เมื่อใด',
#  'ภาค',
#  'คราวนั้น',
#  'ด้าน',
#  'นิดๆ',
#  'ตามๆ',
#  'กำหนด',
#  'แค่',
#  'เดียว',
#  'หากว่า',
#  'ตั้งแต่',
#  'ก่อนหน้านี้',
#  'ระยะๆ',
#  'นำ',
#  'ขวางๆ',
#  'อย่างหนึ่ง',
#  'นั่นไง',
#  'ในที่',
#  'ยิ่งแล้ว',
#  'เพื่อให้',
#  'คราวใด',
#  'ครั้งไหน',
#  'แค่นั้น',
#  'ผ่านๆ',
#  'ไฉน',
#  'ถึงแก่',
#  'ทุกครา',
#  'ตลอดเวลา',
#  'พวกแก',
#  'บ่อยครั้ง',
#  'คราวละ',
#  'ตลอดทั่ว',
#  'จวนจะ',
#  'นี่',
#  'อยู่',
#  'บาง',
#  'เสมือนว่า',
#  'เห็นควร',
#  'เป็นอาทิ',
#  'ขอ',
#  'ซึ่ง',
#  'อย่างยิ่ง',
#  'นี้',
#  'เช่นก่อน',
#  'หลังจาก',
#  'จนขณะนี้',
#  'ไป่',
#  'พร้อมกัน',
#  'เช่นกัน',
#  'พวกกัน',
#  'เล่าว่า',
#  'ฯ',
#  'ถึงบัดนั้น',
#  'เพียงเพื่อ',
#  'ร่วมมือ',
#  'ยิ่งใหญ่',
#  'เสียก่อน',
#  'เล็กน้อย',
#  'นั้นไว',
#  'ง่ายๆ',
#  'มีแต่',
#  'เหล่านั้น',
#  'คราวก่อน',
#  'ครั้งนี้',
#  'ยาว',
#  'เช่นที่ว่า',
#  'ซะก่อน',
#  'เท่านี้',
#  'รือ',
#  'เสร็จกัน',
#  'คราวๆ',
#  'เท่ากัน',
#  'เป็น',
#  'ส่วนด้อย',
#  'จัดแจง',
#  'พื้นๆ',
#  'นี่แน่ะ',
#  'พวกท่าน',
#  'ต่างก็',
#  'ยิ่งจน',
#  'ทุกวันนี้',
#  'ตามที่',
#  'ฉะนี้',
#  'โตๆ',
#  'ทั้งหมด',
#  'เก็บ',
#  'รวดเร็ว',
#  'สบาย',
#  'รึว่า',
#  'มัก',
#  'แม้กระทั่ง',
#  'บอกแล้ว',
#  'พอกัน',
#  'ช่วงแรก',
#  'ค่อนข้างจะ',
#  'จัดหา',
#  'ตนเอง',
#  'ส่วนใหญ่',
#  'เช่นเมื่อ',
#  'เอ็ง',
#  'นี้เอง',
#  'เกือบ',
#  'ทุกๆ',
#  'ครั้ง',
#  'แต่อย่างใด',
#  'ครัน',
#  'ตลอดจน',
#  'มั้ยนั่น',
#  'ช่วงหน้า',
#  'จำเป็น',
#  'หรือไง',
#  'เมื่อไหร่',
#  'ขาด',
#  'ข้าพเจ้า',
#  'เฉกเช่น',
#  'เปลี่ยน',
#  'เต็มไปหมด',
#  'ถูก',
#  'ทุกอัน',
#  'จริงๆจังๆ',
#  'อย่างดี',
#  'คิด',
#  'คราว',
#  'แค่เพียง',
#  'ทั่ว',
#  'หากแม้น',
#  'แล้วเสร็จ',
#  'นัก',
#  'เชื่อว่า',
#  'คราไหน',
#  'เฉยๆ',
#  'เสียนั่นเอง',
#  'จนกว่า',
#  'เหตุผล',
#  'อย่างเดียว',
#  'ที',
#  'เสียนี่',
#  'เพื่อว่า',
#  'เพียงไหน',
#  'ผู้',
#  'ตนฯ',
#  'นับแต่นี้',
#  'ยังงั้น',
#  'พวกคุณ',
#  'สิ่งนั้น',
#  'พบว่า',
#  'ค่อน',
#  'พวกฉัน',
#  'ใช้',
#  'ตลอดมา',
#  'ในเมื่อ',
#  'คือ',
#  'อย่างเช่น',
#  'ใกล้ๆ',
#  'เราๆ',
#  'ได้แก่',
#  'ถึงแม้',
#  'ครั้งๆ',
#  'ค่อย',
#  'เป็นต้นมา',
#  'ทีละ',
#  'ทุกครั้ง',
#  'นู้น',
#  'ที่แห่งนั้น',
#  'ช่วงท้าย',
#  'เกิด',
#  'ตลอดกาลนาน',
#  'แม้นว่า',
#  'เหตุนั้น',
#  'บอก',
#  'สูงๆ',
#  'เหตุนี้',
#  'จากนั้น',
#  'พวกโน้น',
#  'ค่อยไปทาง',
#  'ว่า',
#  'ไกล',
#  'หรือเปล่า',
#  'เมื่อคราว',
#  'เสียยิ่ง',
#  'กว้างๆ',
#  'ไม่ว่า',
#  'หรือยัง',
#  'แล้วแต่',
#  'ภายภาค',
#  'ยิ่งกว่า',
#  'แรก',
#  'ครบถ้วน',
#  'ใต้',
#  'คล้ายว่า',
#  'ครับ',
#  'กลุ่ม',
#  'ครบครัน',
#  'เช่นดังเก่า',
#  'เหลือ',
#  'แห่งโน้น',
#  'ยืนยง',
#  'ที่นั้น',
#  'เฉย',
#  'ใหญ่ๆ',
#  'เผื่อ',
#  'พยายาม',
#  'จนแม้',
#  'ออก',
#  'มิใช่',
#  'พึง',
#  'เช่นเดียวกัน',
#  'พอสมควร',
#  'ก็ต่อเมื่อ',
#  'ล้วน',
#  'เห็น',
#  'อย่างนี้',
#  'ตั้ง',
#  'ใกล้',
#  'ขณะหนึ่ง',
#  'เสียแล้ว',
#  'มาก',
#  'ก็ตาม',
#  'นับแต่นั้น',
#  'ถูกต้อง',
#  'เขียน',
#  'ยาวนาน',
#  'จนแม้น',
#  'ทรง',
#  'เท่าไร',
#  'ถึงบัดนี้',
#  'ครั้งหลัง',
#  'กลุ่มก้อน',
#  'รวมถึง',
#  'ค่ะ',
#  'พอๆ',
#  'บางครั้ง',
#  'สู่',
#  'ย่อย',
#  'ปรากฏ',
#  'ยืนนาน',
#  'ทั้ง',
#  'กำลังจะ',
#  'คิดว่า',
#  'หมด',
#  'ครั้งกระนั้น',
#  'ทั้งที',
#  'ซึ่งได้แก่',
#  'ใหญ่โต',
#  'แล้ว',
#  'กับ',
#  'จัดการ',
#  'ไม่ค่อย',
#  'อันไหน',
#  'ประการหนึ่ง',
#  'ล้วนจน',
#  'ปรับ',
#  'พอที่',
#  'มากกว่า',
#  'เมื่อคราวก่อน',
#  'นั้นๆ',
#  'ที่แท้',
#  'ยังงี้',
#  'เดียวกัน',
#  'ฝ่ายใด',
#  'น้อยๆ',
#  'ตลอดทั้ง',
#  'ก็ได้',
#  'ขณะใดๆ',
#  'พึ่ง',
#  'เพียงแต่',
#  'จะ',
#  'เช่น',
#  'ทีเดียว',
#  'ดังกล่าว',
#  'ทีไร',
#  'บน',
#  'นับแต่',
#  'ประสบ',
#  'วันนี้',
#  'ภายหลัง',
#  'เพียงใด',
#  'ที่ใด',
#  'พอควร',
#  'สมัยนั้น',
#  'เป็นแต่',
#  'พวก',
#  'ทีเถอะ',
#  'บัดนี้',
#  'ทั้งๆ',
#  'เช่นดังก่อน',
#  'ครบ',
#  'วัน',
#  'อาจจะ',
#  'แต่ต้อง',
#  'เรื่อย',
#  'มัน',
#  'ดังกับ',
#  'ทว่า',
#  'น่าจะ',
#  'ถ้า',
#  'พร้อมกับ',
#  'ด้วยเพราะ',
#  'ในช่วง',
#  'ใคร',
#  'มุ่งเน้น',
#  'ยังไง',
#  'ปรากฏว่า',
#  'อย่างมาก',
#  'ภายหน้า',
#  'ช่วงนี้',
#  'พอที',
#  'แบบ',
#  'ขณะนี้',
#  'อย่างๆ',
#  'มอง',
#  'ที่สุด',
#  'ดังเก่า',
#  'เพิ่งจะ',
#  'ก็จะ',
#  'ทีๆ',
#  'ซึ่งก็',
#  'ยัง',
#  'ทุกอย่าง',
#  'ฯลฯ',
#  'ยืนยาว',
#  'เท่า',
#  'เมื่อนั้น',
#  'ทั้งคน',
#  'แก',
#  'ใน',
#  'ภาย',
#  'มิได้',
#  'ซึ่งก็คือ',
#  'ต่อ',
#  'หาก',
#  'รวมด้วย',
#  'เถอะ',
#  'ที่ละ',
#  'เรื่อยๆ',
#  'เผื่อว่า',
#  'แสดงว่า',
#  'แท้',
#  'ฉัน',
#  'แค่ไหน',
#  'ช่วงๆ',
#  'ตลอดไป',
#  'มุ่งหมาย',
#  'ด้วยเหตุว่า',
#  'นั่นเอง',
#  'เพิ่ม',
#  'ที่ซึ่ง',
#  'ให้แด่',
#  'ด้วยเหตุเพราะ',
#  'ระหว่าง',
#  'เห็นจะ',
#  'นาง',
#  'ได้รับ',
#  'เช่นเดียวกับ',
#  'เผื่อที่',
#  'โต',
#  'เพียง',
#  'แต่ทว่า',
#  'พอเพียง',
#  'ให้ไป',
#  'ขั้น',
#  'นอกจาก',
#  'แม้ว่า',
#  'พา',
#  'พวกกู',
#  'ทุกตัว',
#  'จนตลอด',
#  'เสมือนกับ',
#  'พร้อมเพียง',
#  'สูงส่ง',
#  'ขณะเดียวกัน',
#  'นำพา',
#  'อดีต',
#  'คง',
#  'ยอมรับ',
#  'ไม่ใช่',
#  'นั่นแหละ',
#  'พวกนี้',
#  'เพื่อ',
#  'เกือบๆ',
#  'นำมา',
#  'ถ้าจะ',
#  'มา',
#  'อย่างไหน',
#  'อีก',
#  'เสียด้วย',
#  'ทั้งหลาย',
#  'จนบัดนี้',
#  'เกินๆ',
#  'แต่นั้น',
#  'จำ',
#  'อยาก',
#  'กล่าวคือ',
#  'พร้อมที่',
#  'สิ้นกาลนาน',
#  'เหตุ',
#  'เมื่อวาน',
#  'เชื่อถือ',
#  'นางสาว',
#  'ผิด',
#  'ปิด',
#  'รวมกัน',
#  'อย่างใด',
#  'จัดงาน',
#  'ไร',
#  'ทุกแห่ง',
#  'ถึงเมื่อใด',
#  'ทั้งตัว',
#  'ซะ',
#  'ด้วยว่า',
#  'อย่างโน้น',
#  'มองว่า',
#  'เท่าที่',
#  'นาย',
#  'จวน',
#  'อย่างไร',
#  'แต่ก่อน',
#  'นี่ไง',
#  'หาความ',
#  'ยิ่งจะ',
#  'จ้ะ',
#  'ไม่ค่อยเป็น',
#  'จู่ๆ',
#  'ตาม',
#  'กันดีกว่า',
#  'คะ',
#  'ที่ๆ',
#  'ถึงแม้จะ',
#  'ตลอดถึง',
#  'เพิ่มเติม',
#  'ทีใด',
#  'สูง',
#  'จรดกับ',
#  'ยก',
#  'แท้จริง',
#  'เกิน',
#  'สูงสุด',
#  'ไหนๆ',
#  'บ้าง',
#  'ประมาณ',
#  'เหล่านี้',
#  'จริงๆ',
#  'เพื่อที่',
#  'แต่ก็',
#  'ค่อนข้าง',
#  'เสียยิ่งนัก',
#  'เฉพาะ',
#  'เป็นอันว่า',
#  'สิ่งนี้',
#  'ควร',
#  'นี่เอง',
#  'เพราะว่า',
#  'เมื่อ',
#  'ของ',
#  'เพื่อที่จะ',
#  'หมดสิ้น',
#  'นับจากนี้',
#  'เช่นที่เคย',
#  'นอกนั้น',
#  'ซะจนถึง',
#  'ยังแต่',
#  'เพียงพอ',
#  'อย่างน้อย',
#  'แห่งนั้น',
#  'นํา',
#  'จง',
#  'แล้วกัน',
#  'บ่อยๆ',
#  'ใหม่',
#  'ดังเคย',
#  'มิฉะนั้น',
#  'ถึงจะ',
#  'ช่วงหลัง',
#  'ตน',
#  'ก่อนหน้า',
#  'สิ้น',
#  'ด้วยเหมือนกัน',
#  'อันที่',
#  'ยกให้',
#  'เพียงไร',
#  'ทํา',
#  'แม้แต่',
#  'ภายใน',
#  'จริง',
#  'สําหรับ',
#  'ประกอบ',
#  'คราวที่',
#  'ช้าๆ',
#  'นอกจากนั้น',
#  'ถึงอย่างไร',
#  'เช่นดังว่า',
#  'คล้ายกับ',
#  'พร้อมด้วย',
#  'นับจากนั้น',
#  'แต่ไหน',
#  'บ่อย',
#  'ข้างล่าง',
#  'นิดหน่อย',
#  'จัดตั้ง',
#  'ขณะนั้น',
#  'นอกจากนี้',
#  'เต็มไปด้วย',
#  'ครั้งหลังสุด',
#  'เหตุไร',
#  'เสียจนถึง',
#  'ซึ่งกันและกัน',
#  'หนอย',
#  'ละ',
#  'ทั้งสิ้น',
#  'เมื่อครั้งก่อน',
#  'ช้านาน',
#  'ยิ่งนัก',
#  'ก็แล้วแต่',
#  'กันไหม',
#  'ทำๆ',
#  'ตามแต่',
#  'คราวไหน',
#  'คล้าย',
#  'จากนี้',
#  'ล้วนแต่',
#  'อันที่จะ',
#  'ฉะนั้น',
#  'ดั่งกับ',
#  'สูงกว่า',
#  'สิ่ง',
#  'ได้',
#  'ณ',
#  'รวมทั้ง',
#  'อื่นๆ',
#  'เท่าไหร่',
#  'แก้ไข',
#  'พร้อมทั้ง',
#  'เป็นแต่เพียง',
#  'จนถึง',
#  'เอง',
#  'เมื่อคืน',
#  'ให้แก่',
#  'ครั้งที่',
#  'จาก',
#  'ส่วนเกิน',
#  'แค่นี้',
#  'นับตั้งแต่',
#  'เยอะแยะ',
#  'ร่วมกัน',
#  'ไกลๆ',
#  'ทัน',
#  'คล้ายกับว่า',
#  'ทุกชิ้น',
#  'ถึง',
#  'จัดให้',
#  'เช่นนี้',
#  'ตลอดกาล',
#  'จน',
#  'จวบ',
#  'ด้วยกัน',
#  'จังๆ',
#  'ช่วย',
#  'นะ',
#  'ผิดๆ',
#  'จำพวก',
#  'เรียก',
#  'นั่นเป็น',
#  'อย่างที่',
#  'ครั้งก่อน',
#  'เสียจนกระทั่ง',
#  'ทุกวัน',
#  'เช่นนั้นเอง',
#  'นิด',
#  'นี้แหล่',
#  'พูด',
#  'ดั่ง',
#  'กันดีไหม',
#  'ได้มา',
#  'ใหญ่',
#  'ครา',
#  'ทุกที',
#  'เช่นใด',
#  'จวนเจียน',
#  'ชาว',
#  'จริงจัง',
#  'ทันทีทันใด',
#  'เมื่อนี้',
#  'อันจะ',
#  'นักๆ',
#  'ทันที',
#  'ไม่เป็นไร',
#  'ตลอดปี',
#  'แห่ง',
#  'หารือ',
#  'มันๆ',
#  'บอกว่า',
#  'ตลอดทั่วทั้ง',
#  'กระผม',
#  'เป็นอันมาก',
#  'การ',
#  'เสียนั่น',
#  'ช้า',
#  'คราวหลัง',
#  'เกี่ยวกัน',
#  'ช่วงที่',
#  'ทำให้',
#  'เป็นเพื่อ',
#  'ก็ดี',
#  'คราใด',
#  'เนี่ยเอง',
#  'เป็นด้วย',
#  'ในระหว่าง',
#  'นับ',
#  'ทั้งมวล',
#  'ข้าง',
#  'แห่งใด',
#  'หนึ่ง',
#  'หรือ',
#  'เพิ่ง',
#  'ขณะที่',
#  'จากนี้ไป',
#  'ไว้',
#  'ทำไม',
#  'รือว่า',
#  'ทาง',
#  'หลาย',
#  'อันใด',
#  'เป็นอันๆ',
#  'ข้าฯ',
#  'ต้อง',
#  'กระนั้น',
#  'นับแต่ที่',
#  'แยะๆ',
#  'พอจะ',
#  'กลับ',
#  'จด',
#  'มี',
#  'ช่วงระหว่าง',
#  'อันที่จริง',
#  'ด้วยเหตุนี้',
#  'เมื่อคราวที่',
#  'ดัง',
#  'คราวหนึ่ง',
#  'พอดี',
#  'ยิ่งขึ้น',
#  'ผู้ใด',
#  'ล่าสุด',
#  'ก่อน',
#  'จึง',
#  'ข้างต้น',
#  'ส่วนน้อย',
#  'ถือว่า',
#  'สมัยโน้น',
#  'ขณะใด',
#  'ดั่งเคย',
#  'กว้าง',
#  'เช่นไร',
#  'ง่าย',
#  'ด้วย',
#  'เสีย',
#  'อย่างไรก็ได้',
#  'ใช่',
#  'น่ะ',
#  'ดังกับว่า',
#  'ที่จริง',
#  'เช่นที่',
#  'ต่างหาก',
#  'มั๊ย',
#  'จ๊ะ',
#  'พอสม',
#  'ยอม',
#  'ค่อยๆ',
#  'เป็นที',
#  'คราวโน้น',
#  'ก็คือ',
#  'นี่นา',
#  'สมัยนี้',
#  'เช่นนั้น',
#  'แค่ว่า',
#  'แต่ไร',
#  'คำ',
#  'ทุกคราว',
#  'เสร็จสิ้น',
#  'ไหน',
#  'เธอ',
#  'จัด',
#  'รวม',
#  'อันๆ',
#  'แม้',
#  'แยะ',
#  'โดย',
#  'ภาคฯ',
#  'ทุกคน',
#  'นอกจากที่',
#  'รวด',
#  'ถึงแม้ว่า',
#  'วันนั้น',
#  'พวกเธอ',
#  'นู่น',
#  'เร็วๆ',
#  'ด้วยที่',
#  'เรียบ',
#  'คล้ายกันกับ',
#  'เช่นดัง',
#  'เคยๆ',
#  'แหละ',
#  'แต่เดิม',
#  'เล็กๆ',
#  'ไม่',
#  'ทำไร',
#  'ส่วนนั้น',
#  'ใคร่จะ',
#  'น่า',
#  'เป็นต้นไป',
#  'จับ',
#  'ย่อม',
#  'แก่',
#  'นี่แหละ',
#  'กระทำ',
#  'บางคราว',
#  'ทุกที่',
#  'บางขณะ',
#  'เปิด',
#  'สำคัญ',
#  'บางครา',
#  'พอ',
#  'ซะจนกระทั่ง',
#  'เป็นเพราะ',
#  'ยังจะ',
#  'เพียงเพราะ',
#  'กระทั่ง',
#  'เป็นเพียงว่า',
#  'ทั้งนั้นเพราะ',
#  'ได้ที่',
#  'ที่แท้จริง',
#  'ด้วยเหตุนั้น',
#  'ด้วยประการฉะนี้',
#  'สืบเนื่อง',
#  'กล่าว',
#  'เสียจน',
#  'ตามด้วย',
#  'พอเหมาะ',
#  'มึง',
#  'พอตัว',
#  'สมัย',
#  'พอแล้ว',
#  'ทันใดนั้น',
#  'ซึ่งกัน',
#  'ช่วง',
#  'ระยะ',
#  'อย่าง',
#  'เป็นๆ',
#  'มั้ยล่ะ',
#  'ครั้งนั้น',
#  'เสียนี่กระไร',
#  'ประการฉะนี้',
#  'สามารถ',
#  'ขณะ',
#  'เกี่ยวข้อง',
#  'ช่วงนั้น',
#  'ส่ง',
#  'น้อย',
#  'ส่วนที่',
#  'เถิด',
#  'มักจะ',
#  'ถึงเมื่อ',
#  'อันละ',
#  'เกือบจะ',
#  'ตลอดระยะเวลา',
#  'หน่อย',
#  'แต่ว่า',
#  '\ufeffๆ',
#  'ให้มา',
#  'อนึ่ง',
#  'ต่าง',
#  'คล้ายกัน',
#  'นั้น',
#  'หมดกัน',
#  'เป็นเพราะว่า',
#  'พวกเขา',
#  'อย่างละ',
#  'รับรอง',
#  'แสดง',
#  'สิ่งใด',
#  'สุดๆ',
#  'ครั้งหนึ่ง',
#  'ครานั้น',
#  'ข้างบน',
#  'ครั้งใด',
#  'ทั้งนั้นด้วย',
#  'คุณ',
#  'ภายใต้',
#  'ถ้าหาก',
#  'เล็ก',
#  'กำลัง',
#  'มิ',
#  'ที่ว่า',
#  'เกี่ยวเนื่อง',
#  'กันเถอะ',
#  'จะได้',
#  'บางแห่ง',
#  'คราวนี้',
#  'ไม่ค่อยจะ',
#  'นอก',
#  'ตลอดทั่วถึง',
#  'วันใด',
#  'เขา',
#  'คงอยู่',
#  'ทุกทาง',
#  'ไง',
#  'ซะจน',
#  'บางๆ',
#  'เสร็จสมบูรณ์',
#  'ก็',
#  'แห่งนี้',
#  'แต่ถ้า',
#  'และ',
#  'ลง',
#  'บางที่',
#  'กว้างขวาง',
#  'ๆ',
#  'กันเอง',
#  'แค่จะ',
#  'ประการ',
#  'แห่งไหน',
#  'เกี่ยวกับ',
#  'ทั้งที่',
#  'บ่อยกว่า',
#  'กันและกัน',
#  'จวบกับ',
#  'เป็นการ',
#  'ร่วม',
#  'ตลอดวัน',
#  'ตลอดศก',
#  'นอกเหนือ',
#  'หน',
#  'ให้ดี',
#  'เป็นที่สุด',
#  'ร่วมด้วย',
#  'ครั้งครา',
#  'ได้แต่',
#  'เริ่ม',
#  'ผล',
#  'ยาก',
#  'เห็นว่า',
#  'เปลี่ยนแปลง',
#  'ตรง',
#  'ประการใด',
#  'อาจ',
#  'เสร็จ',
#  'เป็นดัง',
#  'เมื่อไร',
#  'ที่',
#  'เหล่า',
#  'นาน',
#  'มากมาย',
#  'พวกมัน',
#  'จัง',
#  'เยอะ',
#  'ครานี้',
#  'อย่างไรเสีย',
#  'บางที',
#  'อย่างไรก็',
#  'กัน',
#  'ยังโง้น',
#  'ค่อนมาทาง',
#  'ปฏิบัติ',
#  'ปัจจุบัน',
#  'อย่างนั้น',
#  'เพียงแค่',
#  'จวบจน',
#  'นอกจากว่า',
#  'ส่วน',
#  'นานๆ',
#  'สั้น',
#  'กู',
#  'ที่ไหน',
#  'ถือ',
#  'จ๋า',
#  'บัดเดี๋ยวนี้',
#  'ครั้งละ',
#  'หาใช่',
#  'ส่วนมาก',
#  'ดั่งกับว่า',
#  'ราย',
#  'ก็แค่',
#  'เมื่อก่อน',
#  'เร็ว',
#  'ทุกเมื่อ',
#  'ต่างๆ',
#  'หากแม้นว่า',
#  'ส่วนดี',
#  'จนกระทั่ง',
#  'เอา',
#  'ทั้งนี้',
#  'เช่นดังที่',
#  'เมื่อเช้า',
#  'เป็นเพียง',
#  'ตรงๆ',
#  'คุณๆ',
#  'รับ',
#  'พร้อม',
#  'ข้างเคียง',
#  'ใหม่ๆ',
#  'เต็มๆ',
#  'ส่วนใด',
#  'เพราะ',
#  'สมัยก่อน',
#  'เท่าใด',
#  'สิ่งไหน',
#  'มั้ยนะ',
#  'อาจเป็นด้วย',
#  'หนอ',
#  'เนื่องจาก',
#  'คราหนึ่ง',
#  'อัน',
#  'แต่จะ',
#  'สั้นๆ',
#  'ถูกๆ',
#  'นั่น',
#  'พวกนู้น',
#  'ผ่าน',
#  'แต่เพียง',
#  'ใคร่',
#  'แต่ที่',
#  'กันนะ',
#  'พบ',
#  'บัดดล',
#  'ช่วงถัดไป',
#  'คราวหน้า',
#  'เท่ากับ',
#  'ก่อนๆ',
#  'ขวาง',
#  'เกี่ยวๆ',
#  'จึงจะ',
#  'เข้า',
#  'เชื่อมั่น',
#  'แต่เมื่อ',
#  ...}

# %%
 words = word_tokenize(normalized_text, engine="newmm")
words
# Out:
# ['นาย',
#  'ทักษิณ',
#  'ขยับ',
#  'เรือนจำ',
#  'ผวา',
#  'สื่อ',
#  'หลาย',
#  'สำนัก',
#  'พาด',
#  'พล',
#  'ตอ',
#  'เสรี',
#  'พิศุทธ์',
#  'ฟันธง',
#  'บิ๊ก',
#  'โจ๊ก',
#  'ชนะ',
#  'ปม',
#  'ออก',
#  'ได้ยิน',
#  'ข่าว',
#  'ช่อง',
#  'ว้าย',
#  'ทีวี',
#  'ซึ่ง',
#  'มี',
#  'ทายาท',
#  'ของ',
#  'มหาเศรษฐี',
#  'คนเหนือ',
#  'บอ',
#  'กว่า',
#  'คน',
#  'ไม่',
#  'ดี',
#  'เหยียบ',
#  'เมือง',
#  'มัน',
#  'จะ',
#  'ร้อน',
#  'แล',
#  'เพื่อ',
#  'ไทย',
#  'เป็น',
#  'รัฐบาล',
#  'ค่า',
#  'ไฟ',
#  'ค่า',
#  'น้ำมัน',
#  'ค่า',
#  'แก',
#  'สลด',
#  'ทัก',
#  'รม',
#  'การขนส่ง',
#  'ทางบก',
#  'เตือน',
#  'ประชาชน',
#  'อย่า',
#  'หลงเชื่อ',
#  'แล',
#  'ขา',
#  'ธิ',
#  'การ',
#  'สำนักงาน',
#  'ศาลยุติธรรม',
#  'เผย',
#  'เร่ง',
#  'ตรวจสอบ',
#  'ข้อ',
#  'นวัตกรรม',
#  'แผ่น',
#  'แปะ',
#  'ซึ่ง',
#  'พัฒนา',
#  'โดย',
#  'กรณี',
#  'การ',
#  'พบ',
#  'เพจ',
#  'เฟซบุ๊ก',
#  'ที่',
#  'ใช้',
#  'ชื่อว่า',
#  'สินเชื่อ',
#  'ธุร',
#  'กิ',
#  'ดื่ม',
#  'น้ำเย็น',
#  'ตอน',
#  'อากาศ',
#  'ร้อน',
#  'ไม่',
#  'ได้',
#  'อันตราย',
#  'นะ',
#  'ครับ']

# %%
 filtered_words = [word for word in words if word not in stop_words and word.strip()]
filtered_words
# Out:
# ['ทักษิณ',
#  'ขยับ',
#  'เรือนจำ',
#  'ผวา',
#  'สื่อ',
#  'สำนัก',
#  'พาด',
#  'พล',
#  'ตอ',
#  'เสรี',
#  'พิศุทธ์',
#  'ฟันธง',
#  'บิ๊ก',
#  'โจ๊ก',
#  'ชนะ',
#  'ปม',
#  'ได้ยิน',
#  'ข่าว',
#  'ช่อง',
#  'ว้าย',
#  'ทีวี',
#  'ทายาท',
#  'มหาเศรษฐี',
#  'คนเหนือ',
#  'บอ',
#  'คน',
#  'ดี',
#  'เหยียบ',
#  'เมือง',
#  'ร้อน',
#  'แล',
#  'ไทย',
#  'รัฐบาล',
#  'ค่า',
#  'ไฟ',
#  'ค่า',
#  'น้ำมัน',
#  'ค่า',
#  'สลด',
#  'ทัก',
#  'รม',
#  'การขนส่ง',
#  'ทางบก',
#  'เตือน',
#  'ประชาชน',
#  'อย่า',
#  'หลงเชื่อ',
#  'แล',
#  'ขา',
#  'ธิ',
#  'สำนักงาน',
#  'ศาลยุติธรรม',
#  'เผย',
#  'เร่ง',
#  'ตรวจสอบ',
#  'ข้อ',
#  'นวัตกรรม',
#  'แผ่น',
#  'แปะ',
#  'พัฒนา',
#  'กรณี',
#  'เพจ',
#  'เฟซบุ๊ก',
#  'ชื่อว่า',
#  'สินเชื่อ',
#  'ธุร',
#  'กิ',
#  'ดื่ม',
#  'น้ำเย็น',
#  'ตอน',
#  'อากาศ',
#  'ร้อน',
#  'อันตราย']

# %%
tokenized_sentence = [word.lower() for word in filtered_words]
tokenized_sentence
# Out:
# ['ทักษิณ',
#  'ขยับ',
#  'เรือนจำ',
#  'ผวา',
#  'สื่อ',
#  'สำนัก',
#  'พาด',
#  'พล',
#  'ตอ',
#  'เสรี',
#  'พิศุทธ์',
#  'ฟันธง',
#  'บิ๊ก',
#  'โจ๊ก',
#  'ชนะ',
#  'ปม',
#  'ได้ยิน',
#  'ข่าว',
#  'ช่อง',
#  'ว้าย',
#  'ทีวี',
#  'ทายาท',
#  'มหาเศรษฐี',
#  'คนเหนือ',
#  'บอ',
#  'คน',
#  'ดี',
#  'เหยียบ',
#  'เมือง',
#  'ร้อน',
#  'แล',
#  'ไทย',
#  'รัฐบาล',
#  'ค่า',
#  'ไฟ',
#  'ค่า',
#  'น้ำมัน',
#  'ค่า',
#  'สลด',
#  'ทัก',
#  'รม',
#  'การขนส่ง',
#  'ทางบก',
#  'เตือน',
#  'ประชาชน',
#  'อย่า',
#  'หลงเชื่อ',
#  'แล',
#  'ขา',
#  'ธิ',
#  'สำนักงาน',
#  'ศาลยุติธรรม',
#  'เผย',
#  'เร่ง',
#  'ตรวจสอบ',
#  'ข้อ',
#  'นวัตกรรม',
#  'แผ่น',
#  'แปะ',
#  'พัฒนา',
#  'กรณี',
#  'เพจ',
#  'เฟซบุ๊ก',
#  'ชื่อว่า',
#  'สินเชื่อ',
#  'ธุร',
#  'กิ',
#  'ดื่ม',
#  'น้ำเย็น',
#  'ตอน',
#  'อากาศ',
#  'ร้อน',
#  'อันตราย']

# %%
def cleanText(sentences):
    tokenized_sentences = []
    cleaned_sentences = []  # เพิ่มคอลัมน์เก็บประโยคที่ทำความสะอาดแล้ว
    
    for txt in sentences:
        # แปลงเป็น string
        t = str(txt)

        # ลบตัวอักษรที่ไม่ใช่ภาษาไทย
        cleaned_text = re.sub('[^ก-๙]', '', t)

        # Normalize ข้อความ (เช่น การปรับสระให้เป็นรูปแบบเดียวกัน)
        normalized_text = normalize(cleaned_text)

        # ดึง stopwords ภาษาไทย
        stop_words = set(thai_stopwords())

        # ตัดคำโดยใช้ engine "newmm" สำหรับการตัดคำภาษาไทย
        words = word_tokenize(normalized_text, engine="newmm")

        # ลบ stopwords และคำที่มีช่องว่าง
        filtered_words = [word for word in words if word not in stop_words and word.strip()]

        # แปลงเป็น lowercase
        tokenized_sentence = [word.lower() for word in filtered_words]

        # เก็บผลลัพธ์ของการตัดคำ
        tokenized_sentences.append(tokenized_sentence)

        # เก็บผลลัพธ์ของประโยคที่ทำความสะอาดแล้ว
        cleaned_sentence = " ".join(tokenized_sentence)
        cleaned_sentences.append(cleaned_sentence)

    return cleaned_sentences, tokenized_sentences  # คืนค่า 2 ค่า: ประโยคที่ทำความสะอาดแล้ว และการตัดคำ

# %%
df_fake['cleantext'], tokenized_sentences = cleanText(txt)

# %%
fake = df_fake['cleantext']

# %%
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow
from keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, GRU, LSTM,Bidirectional, Embedding, Dropout,BatchNormalization
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
# Out:
# 2024-09-18 14:06:14.553339: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-18 14:06:17.002122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def cre_tokenizer(tokenized_sentences ,filters = ' '):
    tok = Tokenizer(filters = filters)
    tok.fit_on_texts(tokenized_sentences)
    return tok

# %%
bag_of_word = cre_tokenizer(fake)

# %%
bag_size = len(bag_of_word.word_index)  + 1
bag_size
# Out:
# 8675

# %%
def max_len(tokenized_sentences):
    # ใช้ len() โดยตรงในแต่ละลิสต์ของคำ
    return max(len(cleaned_sentences) for cleaned_sentences in tokenized_sentences)

# %%
max_sentence_length = max_len(tokenized_sentences)
max_sentence_length
# Out:
# 1682

# %%
min_sentence_length = min(len(cleaned_sentences) for cleaned_sentences in tokenized_sentences)
min_sentence_length
# Out:
# 0

# %%
def min_len(tokenized_sentences):
    # ใช้ len() โดยตรงในแต่ละลิสต์ของคำ
    return min(len(cleaned_sentences) for cleaned_sentences in tokenized_sentences)

# %%
min_sentence_length = min_len(tokenized_sentences)
min_sentence_length
# Out:
# 0

# %%
tokenized_sentence = [["I", "love", "coding"], ["Hello", "world"], ["Python", "is", "fun"]]
min_sentence_length = min(len(sentence) for sentence in tokenized_sentence)
print("Minimum sentence length:", min_sentence_length)
# Out:
# Minimum sentence length: 2

# %%
max_sentence_lengths = max_len(tokenized_sentence)
max_sentence_lengths
# Out:
# 3
